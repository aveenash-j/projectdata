# %% [markdown]
# # Capstone Project
#
# In this project, I have saved the pincodes data of Toronto from the wikipedia page and used Python codes to manipulate the data.

# %%
import pandas as pd
import numpy as np
url="https://s3.eu-geo.objectstorage.softlayer.net/pythonbasicsfordatascienceproject-donotdelete-pr-f33dkdsygu1p8m/Datascienceproj.csv?response-content-disposition=attachment%3B%20filename%3D%22Datascienceproj.csv%22&response-content-type=text%2Fcsv&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20200402T210105Z&X-Amz-SignedHeaders=host&X-Amz-Expires=86400&X-Amz-Credential=2f7eace9ce194c698b629850154cb505%2F20200402%2Feu-geo%2Fs3%2Faws4_request&X-Amz-Signature=01c747464be4e76b7b433b13a4fdb2ceb47352baf0b2fc207ad32979708dece7"
df=pd.read_csv(url)
df
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 178         M5Z      Not assigned
# 179         M6Z      Not assigned
# 180         M7Z      Not assigned
# 181         M8Z         Etobicoke
# 182         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 178                                                NaN
# 179                                                NaN
# ...

# %% [markdown]
# In this step, I have removed the Not assigned Borough values from the dataset. I have also checked if there are any NaN values in the Neighborhood column after performing this operation.

# %%
df.Borough != "Not assigned"
dataset = df[df.Borough != "Not assigned"]
dataset
# Out:
#     Postal code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 163         M8X         Etobicoke
# 168         M4Y  Downtown Toronto
# 171         M7Y      East Toronto
# 172         M8Y         Etobicoke
# 181         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 163    The Kingsway / Montgomery Road / Old Mill North
# 168                               Church and Wellesley
# ...

# %%
dataset=dataset[dataset.Neighborhood != "NaN"]

# %%
dataset
# Out:
#     Postal code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 163         M8X         Etobicoke
# 168         M4Y  Downtown Toronto
# 171         M7Y      East Toronto
# 172         M8Y         Etobicoke
# 181         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 163    The Kingsway / Montgomery Road / Old Mill North
# 168                               Church and Wellesley
# ...

# %%
dataset.shape
# Out:
# (106, 3)

# %%
import os
os.cwd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5925e704f416> in <module>
#       1 import os
# ----> 2 os.cwd()
#
# AttributeError: module 'os' has no attribute 'cwd'
